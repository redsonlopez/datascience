# %%
from datetime import datetime

import requests
from bs4 import BeautifulSoup
import pandas as pd

texto_string = requests.get("https://globoesporte.globo.com/").text
hora_extracao = datetime.now().strftime("%d-%m-%Y %H:%M:%S")

bsp_texto = BeautifulSoup(texto_string, "html.parser")
lista_noticias = bsp_texto.find_all("div", attrs = {"class":"feed-post-body"})
print("Quantidade de manchetes = ", len(lista_noticias))
lista_noticias[0].contents

lista_noticias[0].contents[1].text.replace('"',"")

lista_noticias[0].find("a").get("href")

descricao = lista_noticias[0].contents[2].text
if not descricao:
  descricao = noticias.find("div", attrs = {"class": "bstn-related"})
  descricao = descricao.text if descricao else None
descricao

metadados = lista_noticias[0].find("div", attrs = {"class": "feed-post-metadata"})

time_delta = metadados.find("span", attrs = {"class": "feed-post-datetime"})
secao = metadados.find("span", attrs = {"class": "feed-post-metadata-section"})

time_delta = time_delta.text if time_delta else None
secao = secao.text if secao else None

print("time_delta = ", time_delta)
print("secao = ", secao)

dados = []

for noticias in lista_noticias:
  manchete = noticias.contents[1].text.replace('"', "")
  link = noticias.find("a").get("href")

  descricao = noticias.contents[2].text
  if not descricao:
    descricao = noticias.find("div", attrs = {"class": "bstn-related"})
    descricao = descricao.text if descricao else None

  metadados = noticias.find("div", attrs = {"class": "feed-post-metadata"})
  time_delta = metadados.find("span", attrs = {"class": "feed-post-datetime"})
  secao = metadados.find("span", attrs = {"class": "feed-post-metadata-section"})

  time_delta = time_delta.text if time_delta else None
  secao = secao.text if secao else None

  dados.append((manchete, descricao, link, secao, hora_extracao, time_delta))

df = pd.DataFrame(dados, columns= ["manchete", "descrição", "link", "seção", "hora_extração", "time_delta"])
df.head()

class ExtracaoPortal:
  def __init__(self):
    self.portal = None

  def extrair(self, portal):
    self.portal = portal
    texto_string = requests.get("https://globoesporte.globo.com/").text
    hora_extracao = datetime.now().strftime("%d-%m-%Y %H:%M:%S")

    bsp_texto = BeautifulSoup(texto_string, "html.parser")
    lista_noticias = bsp_texto.find_all("div", attrs = {"class": "feed-post-body"})

    dados = []

    for noticias in lista_noticias:
      manchete = noticias.contents[1].text.replace('"',"")
      link = noticias.find("a").get("href")

      descricao = noticias.contents[2].text
      if not descricao:
        descricao = noticias.find("div", attrs = {"class": "bstn-related"})
        descricao = descricao.text if descricao else None

      metadados = noticias.find("div", attrs = {"class": "feed-post-metadata"})
      time_delta = metadados.find("span", attrs = {"class": "feed-post-datetime"})
      secao = metadados.find("span", attrs = {"class": "feed-post-metadata-section"})

      time_delta = time_delta.text if time_delta else None
      secao = secao.text if secao else None

      dados.append((manchete, descricao, link, secao, hora_extracao, time_delta))

    df = pd.DataFrame(dados, columns = ["manchete", "descrição", "link", "seção", "hora_extração", "time_delta"])
    return df

df = ExtracaoPortal().extrair("https://globoesporte.com/")
df.head()
# Out:
# Quantidade de manchetes =  7
# time_delta =  Há 48 minutos
# secao =   corinthians
#                                             manchete  \
# 0  Haaland de Itaquera? Atacante do Corinthians q...
# 1  EA FC 24: Haaland goleia Luva de Pedreiro em p...
# 2  De volta à Juventus, Kaio Jorge diz estar 100%...
# 3  Vitor Belfort diz que filho Davi pode superar ...
# 4  Rodrigo Moledo, do Inter, é suspenso pela Conm...
#
#                                            descrição  \
# 0  Felipe Augusto fez o gol da vitória contra o U...
# 1  Haaland viraliza ao desfilar com carro de R$ 1...
# 2  Jogador diz que 70% das propostas recebidas sã...
# 3  Ex-campeão do UFC afirma que primogênito preci...
# 4  Goleiro Rochet chega a Porto Alegre para assin...
#
#                                                 link                seção  \
# 0  https://ge.globo.com/futebol/times/corinthians...         corinthians
# 1  https://ge.globo.com/esports/fifa/noticia/2023...                fifa
# 2  https://ge.globo.com/pe/futebol/noticia/2023/0...             futebol
# 3  https://ge.globo.com/futebol-americano/noticia...   futebol americano
# 4  https://ge.globo.com/rs/futebol/times/internac...       internacional
#
#          hora_extração     time_delta
# 0  13-07-2023 22:30:18  Há 47 minutos
# 1  13-07-2023 22:30:18     Há 4 horas
# 2  13-07-2023 22:30:18     Há 2 horas
# 3  13-07-2023 22:30:18     Há 2 horas
# 4  13-07-2023 22:30:18  Há 46 minutos
