# %% [markdown]
# # <b>Programação Orientada a Objetos<br></b>
# <i>Estudo 02_2<br>

# %%
#@title Classe Vendas

class Vendas:
  """
  Esta classe prepara a base de vendas para ser consumida.
  """

  def __init__(self, base_vendas, base_categoria):
    """
    Inicializa o objetivo com as bases de vendas e categoria.
    """
    self.base_vendas= base_vendas
    self.base_categoria= base_categoria

  def remover_vendas_inconcluidas(self):
    """
    Remove as vendas canceladas e com pagamento recusado.
    """
    pass

  def cruzar_bases(self):
    """
    Inclui as informações de categoria e subcategoria na base de vendas.
    """
    pass

# %%
#@title Vendas Consolidadas

class VendasConsilidas:
  """
  Esta classe gera relatórios consolidados de vendas.
  """

  def __init__(self, base_vendas_tratada):
    """
    Inicializa o objeto com a base de vendas tratada pela classe vendas.
    """
    self.base_vendas_tratada= base_vendas_tratada

  def consolidar_vendas_total(self):
    """
    Consolida o valor total de vendas mensais.
    """
    pass

  def consolidar_vendas_categoria(self):
    """
    Consolida o valor mensal de vendas por categoria.
    """
    pass

  def consolidar_vendas_subcategoria(self):
    """
    Consolida o valor mensal de vendas por subcategoria.
    """
    pass
