# %%
import pandas as pd

# %run "/content/drive/MyDrive/Colab Notebooks/oop_dataprep_titanic.ipynb"
# %run "/content/drive/MyDrive/Colab Notebooks/oop_model.ipynb"

# %%
df= pd.read_csv("/content/drive/MyDrive/datasets/titanic_train.csv")

# %%
dp= DataPrep(df)

# %%
df_treino, df_teste= dp.preparar_dados()

# %%
m= Model(df_treino, df_teste)

# %%
m.fit()

# %%
m.score()
# Out:
# 0.7873134328358209
