# %% [markdown]
# ## <b><i>Análise de Dados </b>'Gorjetas'</i>
#
# <i>Registros obtidos de um restaurante, provavelmente no ano de 1990</i><br><br>
#
# <b>Este conjunto de dados contém as seguintes informações:</b><br><br><i>
# **total_bill:** valor total da conta.<br>
# **tip:** valor da gorjeta.<br>
# **sex:** sexo da pessoa que pagou a conta.<br>
# **smoker:** indica se a pessoa que pagou a conta é fumante.<br>
# **day:** dia da semana<br>
# **time:** horário da refeição: almoço (lunch) ou jantar (dinner).<br>
# **size:** indica o número de pessoas que estavam na mesa.<br>

# %%
import seaborn as sns
df= sns.load_dataset("tips")

df.head(3) # Visualização das colunas e dos 3 primeiros registros
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# <b>Nova coluna para porcentagem do garçom

# %%
df["waiter_percent"]= round((df["tip"] / df["total_bill"])* 100)
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  waiter_percent
# 0       16.99  1.01  Female     No  Sun  Dinner     2             6.0
# 1       10.34  1.66    Male     No  Sun  Dinner     3            16.0

# %%
import matplotlib.pyplot as plt
plt.rcParams["axes.spines.top"]= False
plt.rcParams["axes.spines.right"]= False # Configurações fixas para gráficos

# %% [markdown]
# <b>Relação entre o valor da gorjeta e o dia da semana

# %%
ax= sns.barplot(data= df, x="day", y= "tip")

# %% [markdown]
# <b>Valor médio da gorjeta por sexo

# %%
ax= sns.barplot(data= df, x= "sex", y= "tip")

# %% [markdown]
# <b>Valor médio da gorjeta pelo horário da refeição

# %%
ax= sns.barplot(data= df, x= "time", y= "tip")

# %% [markdown]
# <b>Relação e linearidade entre o valor total da conta e a gorjeta

# %%
ax= sns.regplot(data= df, x= "total_bill", y= "tip")

# %% [markdown]
# <b>Relação e linearidade entre o valor total da conta e a porcentagem do garçom

# %%
ax= sns.regplot(data= df, x= "total_bill", y= "waiter_percent")

# %% [markdown]
# <b>Distribuição entre os valores da conta

# %%
ax= sns.histplot(data= df, x="total_bill")

# %% [markdown]
# <b>Distribuição dos valores das gorjetas

# %%
ax= sns.histplot(data= df, x="tip")
