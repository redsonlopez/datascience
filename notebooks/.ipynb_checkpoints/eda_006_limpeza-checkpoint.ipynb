# %%
import pandas as pd

df1= pd.DataFrame({
    "nomes": "  Howard   Belmont; Ian  Silva  ;Peter Torrez;Jonah Stark;Kellie Key".split(";"),
    "cpfs": "111.111.111-11 222.222.222-22 333.333.333-33 444.444.444-44 555.555.555-55".split(),
    "emails": "risus.varius@dictumPhasellusin.ca Nunc@vulputate.ca fames.ac.turpis@cursusa.org non@felisullamcorper.org eget.dictum.placerat@necluctus.co.uk".split(),
    "idades": [32, 22, 25, 29, 38]
})

df2= pd.DataFrame({
    "nomes": "Jonah Stark;Kellie Key".split(";"),
    "cpfs": "444.444.444-44 555.555.555-55".split(),
    "emails": "non@felisullamcorper.org eget.dictum.placerat@necluctus.co.uk".split(),
    "idades": [29, 38]
})

df= pd.concat([df1, df2])

df.head()
# Out:
#                 nomes            cpfs                                emails  \
# 0    Howard   Belmont  111.111.111-11     risus.varius@dictumPhasellusin.ca
# 1        Ian  Silva    222.222.222-22                     Nunc@vulputate.ca
# 2        Peter Torrez  333.333.333-33           fames.ac.turpis@cursusa.org
# 3         Jonah Stark  444.444.444-44              non@felisullamcorper.org
# 4          Kellie Key  555.555.555-55  eget.dictum.placerat@necluctus.co.uk
#
#    idades
# 0      32
# 1      22
# 2      25
# 3      29
# 4      38

# %%
df = df.astype(str)

# %%
df = df.applymap(lambda x: x.strip())

# %%
df["idades"] = df["idades"].astype(int)

# %%
df.replace(to_replace= "\s+", value= " ", inplace= True, regex= True)

# %%
df.head()
# Out:
#             nomes            cpfs                                emails  \
# 0  Howard Belmont  111.111.111-11     risus.varius@dictumPhasellusin.ca
# 1       Ian Silva  222.222.222-22                     Nunc@vulputate.ca
# 2    Peter Torrez  333.333.333-33           fames.ac.turpis@cursusa.org
# 3     Jonah Stark  444.444.444-44              non@felisullamcorper.org
# 4      Kellie Key  555.555.555-55  eget.dictum.placerat@necluctus.co.uk
#
#    idades
# 0      32
# 1      22
# 2      25
# 3      29
# 4      38

# %% [markdown]
# df.to_csv("/path/file.txt", encoding='latin1', sep= ';', index= True, header= None)
# <br>
# <br>
# df= pd.read_csv("/path/file.txt", encoding='latin1', sep= ';', header= None, index_col= 0, skiprows= 1, usecols=lambda column: column != 'coluna16')
