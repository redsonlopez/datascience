# %%
import pandas as pd
import folium

saude_fidedigna= pd.read_csv("~/Downloads/datacic/unidades/Saúde - Fidedigna.csv", index_col= None)
atributos= ["REGIONAL", "UNIDADE DE SAÚDE", "LOGRADOURO POR GEORREFERENCIAMENTO", 
            "NOME DO LOGRADOURO POR GEORREFERENCIAMENTO", "NÚMERO POR GEORREFERENCIAMENTO", "BAIRRO",
            "COORDENADAS GEOGRÁFICAS POR GEORREFERENCIAMENTO"]
fidedigna= saude_fidedigna[atributos]
fidedigna.shape
# Out:
# (432, 7)

# %%
fidedigna.loc[(fidedigna["NOME DO LOGRADOURO POR GEORREFERENCIAMENTO"] == "ANDIROBA") &\
(fidedigna["NÚMERO POR GEORREFERENCIAMENTO"] == "100") & (fidedigna["BAIRRO"] == "SAO PAULO"),\
"COORDENADAS GEOGRÁFICAS POR GEORREFERENCIAMENTO"] = "-19.865590, -43.926254"

fidedigna.loc[fidedigna["COORDENADAS GEOGRÁFICAS POR GEORREFERENCIAMENTO"] == "--19.83279347, -43.94601295",\
"COORDENADAS GEOGRÁFICAS POR GEORREFERENCIAMENTO"] = "-19.83279347, -43.94601295"

fidedigna[['Latitude', 'Longitude']] = fidedigna['COORDENADAS GEOGRÁFICAS POR GEORREFERENCIAMENTO']\
.str.rsplit(',', n=1, expand=True).astype(float).copy()
fidedigna.shape
# Out:
# /tmp/ipykernel_5796/3576834884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fidedigna.loc[(fidedigna["NOME DO LOGRADOURO POR GEORREFERENCIAMENTO"] == "ANDIROBA") &\
# /tmp/ipykernel_5796/3576834884.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fidedigna.loc[fidedigna["COORDENADAS GEOGRÁFICAS POR GEORREFERENCIAMENTO"] == "--19.83279347, -43.94601295",\
# /tmp/ipykernel_5796/3576834884.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fidedigna[['Latitude', 'Longitude']] = fidedigna['COORDENADAS GEOGRÁFICAS POR GEORREFERENCIAMENTO']\
# /tmp/ipykernel_5796/3576834884.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fidedigna[['Latitude', 'Longitude']] = fidedigna['COORDENADAS GEOGRÁFICAS POR GEORREFERENCIAMENTO']\
# (432, 9)

# %%
mymap = folium.Map(location=[fidedigna['Latitude'].mean(), fidedigna['Longitude'].mean()], zoom_start=11.5)
for index, row in fidedigna.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], popup= "{}, {}, {}, {}"
                  .format(row['LOGRADOURO POR GEORREFERENCIAMENTO'], row['NOME DO LOGRADOURO POR GEORREFERENCIAMENTO'],
                          row['NÚMERO POR GEORREFERENCIAMENTO'], row["BAIRRO"])).add_to(mymap)

folium.Marker([-19.923776, -43.936434], popup= "PBH", icon= folium.Icon(color= "darkred", icon= "info-sign")).add_to(mymap)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e40deddf22f1a88f6768b6466685c18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e40deddf22f1a88f6768b6466685c18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e40deddf22f1a88f6768b6466685c18 = L.map(
#                 &quot;map_3e40deddf22f1a88f6768b6466685c18&quot;,
#                 {
#                     center: [-19.90302666722568, -43.955238242507505],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5acfab13bb338b878d2792b89ec2690b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5acfab13bb338b878d2792b89ec2690b.addTo(map_3e40deddf22f1a88f6768b6466685c18);
#
#
#             var marker_83fd6ca8704a4f46cd0a39810eee86f9 = L.marker(
#                 [-19.979142, -44.0131636],
#                 {}
#             ).addTo(map_3e40deddf22f1a88f6768b6466685c18);
#
#
#         var popup_b80fa48949756c4645b25b34fc5593c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04e9826ddae07d2613b9c360c458a03a = $(`&lt;div id=&quot;html_04e9826ddae07d2613b9c360c458a03a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;RUA, PINHEIRO CHAGAS, 252, BARREIRO&lt;/div&gt;`)[0];
#                 popup_b80fa48949756c4645b25b34fc5593c0.setContent(html_04e9826ddae07d2613b9c360c458a03a);
#
#
#
#         marker_83fd6ca8704a4f46cd0a39810eee86f9.bindPopup(popup_b80fa48949756c4645b25b34fc5593c0)
#         ;
#
#
#
#
#             var marker_8ab9e99870f72de563c2fdf7eebfdf10 = L.marker(
#                 [-19.81991037, -43.9630504],
#                 {}
#             ).addTo(map_3e40deddf22f1a88f6768b6466685c18);
#
#
#         var popup_0cc701575a387a0c7b7665a030dcc124 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7673f4507654948adfead88b76a3d45b = $(`&lt;div id=&quot;html_7673f4507654948adfead88b76a3d45b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;RUA, MARIANA AMELIA DE AZEVEDO, 21, SAO JOAO BATISTA&lt;/div&gt;`)[0];
#                 popup_0cc701575a387a0c7b7665a030dcc124.setContent(html_7673f4507654948adfead88b76a3d45b);
#
#
#
#         marker_8ab9e99870f72de563c2fdf7eebfdf10.bindPopup(popup_0cc701575a387a0c7b7665a030dcc124)
#         ;
#
#
#
#
#             var marker_892e8eb6007b69e0204c9f8a60da1fd7 = L.marker(
#                 [-19.96251532, -44.00036632],
#                 {}
#             ).addTo(map_3e40deddf22f1a88f6768b6466685c18);
#
#
#         var popup_1114c7fb39faed0f1519f40213f8971b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0de94eca4226c6b1ae968031417c0886 = $(`&lt;div id=&quot;html_0de94eca4226c6b1ae968031417c0886&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;RUA, DOS INDUSTRIARIOS, 289, BAIRRO DAS INDUSTRIAS I&lt;/div&gt;`)[0];
#                 popup_1114c7fb39faed0f1519f40213f8971b.setContent(html_0de94eca4226c6b1ae968031417c0886);
#
#
#
#         marker_892e8eb6007b69e0204c9f8a60da1fd7.bindPopup(popup_1114c7fb39faed0f1519f40213f8971b)
#         ;
#
#
#
#
#             var marker_128ca7fcf89ee3122d3a19e43fab887e = L.marker(
#                 [-19.97354993, -44.01430169],
#                 {}
#             ).addTo(map_3e40deddf22f1a88f6768b6466685c18);
#
#
#         var popup_551f3c6b11c31f9424b9b8cbfa69d5ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ecf00b81b4d622147cb4f67a0ad4928e = $(`&lt;div id=&quot;html_ecf00b81b4d622147cb4f67a0ad4928e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;RUA, DESEMBARGADOR RIBEIRO DA LUZ, 29, BARREIRO&lt;/div&gt;`)[0];
#                 popup_551f3c6b11c31f9424b9b8cbfa69d5ed.setContent(html_ecf00b81b4d622147cb4f67a0ad4928e);
#
#
#
#         marker_128ca7fcf89ee3122d3a19e43fab887e.bindPopup(popup_551f3c6b11c31f9424b9b8cbfa69d5ed)
#         ;
#
#
#
#
#             var marker_793a7cc5a74bed4cb5677e703e484d17 = L.marker(
#                 [-19.97796527, -44.01341239],
#                 {}
#             ).addTo(map_3e40deddf22f1a88f6768b6466685c18);
#
#
#         var popup_51d8d11d9e33729b91f728dbc1215851 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30b5fadf2d52a09b841e91fa383e8a88 = $(`&lt;div id=&quot;html_30b5fadf2d52a09b841e91fa383e8a88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;RUA, PINHEIRO CHAGAS, 125, BARREIRO&lt;/div&gt;`)[0];
#                 popup_51d8d11d9e33729b91f728dbc1215851.setContent(html_30b5fadf2d52a09b841e91fa383e8a88);
#
#
#
#         marker_793a7cc5a74bed4cb5677e703e484d17.bindPopup(popup_51d8d11d9e33729b91f728dbc1215851)
#         ;

# %%
mymap.save('mapa_saude.html')
