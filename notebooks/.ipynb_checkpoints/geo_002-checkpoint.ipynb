# %%
import pandas as pd
import folium

df= pd.read_csv("~/Downloads/Saúde - Fidedigna.csv")
print(f"Linhas= {df.shape[0]}, Colunas= {df.shape[1]}")
# Out:
# Linhas= 432, Colunas= 199

# %%
atributos= ["FOI REALIZADA VISITA?", "REGIONAL", "UNIDADE DE SAÚDE", "LOGRADOURO POR GEORREFERENCIAMENTO", 
            "NOME DO LOGRADOURO POR GEORREFERENCIAMENTO", "NÚMERO POR GEORREFERENCIAMENTO", "BAIRRO",
            "COORDENADAS GEOGRÁFICAS POR GEORREFERENCIAMENTO"]
df= df[atributos]
df= df[df["FOI REALIZADA VISITA?"] == "NÃO"]
print(f"Linhas= {df.shape[0]}, Colunas= {df.shape[1]}")
# Out:
# Linhas= 47, Colunas= 8

# %%
df[['Latitude', 'Longitude']] = df['COORDENADAS GEOGRÁFICAS POR GEORREFERENCIAMENTO'].str.rsplit(',', n=1, expand=True).astype(float)
display(df.head(2))
df.shape
# Out:
#    FOI REALIZADA VISITA?    REGIONAL  \
# 46                   NÃO  CENTRO-SUL
# 61                   NÃO  CENTRO-SUL
#
#                                    UNIDADE DE SAÚDE  \
# 46                   ACADEMIA DA CIDADE VILA FÁTIMA
# 61  CENTRO DE REFERÊNCIA EM REABILITAÇÃO CENTRO-SUL
#
#    LOGRADOURO POR GEORREFERENCIAMENTO  \
# 46                               BECO
# 61                                RUA
#
#    NOME DO LOGRADOURO POR GEORREFERENCIAMENTO NÚMERO POR GEORREFERENCIAMENTO  \
# 46                                 DONA BENTA                            145
# 61      PROFESSOR OCTAVIO COELHO DE MAGALHAES                            111
#
#                      BAIRRO COORDENADAS GEOGRÁFICAS POR GEORREFERENCIAMENTO  \
# 46  NOSSA SENHORA DE FATIMA                      -19.93440545, -43.90432633
# 61              MANGABEIRAS                      -19.94879522, -43.91706728
#
#      Latitude  Longitude
# 46 -19.934405 -43.904326
# 61 -19.948795 -43.917067
# (47, 10)

# %%
# Criar um mapa
mymap = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=12)

folium.Marker([-19.924533, -43.936590], popup= "GCUST", icon= folium.Icon(color= "darkred", icon= 'info-sign')).add_to(mymap)
folium.Marker([-19.9803, -44.0574], popup= "Hedson", icon= folium.Icon(color= "gray", icon= "info-sign")).add_to(mymap)
folium.Marker([-19.844487, -43.939143], popup= "Joâo Paulo", icon= folium.Icon(color= "gray", icon= "info-sign")).add_to(mymap)
folium.Marker([-19.905747, -44.012520], popup= "Thiago", icon= folium.Icon(color= "gray", icon= "info-sign")).add_to(mymap)
folium.Marker([-19.871840, -44.008654], popup= "Eros", icon= folium.Icon(color= "gray", icon= "info-sign")).add_to(mymap)

# Adicionar marcadores ao mapa
for index, row in df.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], popup= "{}, {}, {}, {}, {}"
                  .format(row['UNIDADE DE SAÚDE'], row['LOGRADOURO POR GEORREFERENCIAMENTO'], row['NOME DO LOGRADOURO POR GEORREFERENCIAMENTO'],
                          row['NÚMERO POR GEORREFERENCIAMENTO'], row["BAIRRO"])).add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97e63e2294b874e399894d8b51b7f357 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97e63e2294b874e399894d8b51b7f357&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97e63e2294b874e399894d8b51b7f357 = L.map(
#                 &quot;map_97e63e2294b874e399894d8b51b7f357&quot;,
#                 {
#                     center: [-19.929711089361707, -43.933872429999994],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0568d4f4fbdc3b61eb6350f521104e5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a0568d4f4fbdc3b61eb6350f521104e5.addTo(map_97e63e2294b874e399894d8b51b7f357);
#
#
#             var marker_6ce2ea6dd977707f173c5bbed02da5f8 = L.marker(
#                 [-19.924533, -43.93659],
#                 {}
#             ).addTo(map_97e63e2294b874e399894d8b51b7f357);
#
#
#             var icon_e27452635a4eb29daa07744f877b872b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6ce2ea6dd977707f173c5bbed02da5f8.setIcon(icon_e27452635a4eb29daa07744f877b872b);
#
#
#         var popup_eb51e0140988d045a006449577b6ccd6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cf6a9f18d1effd7aae5871b0c2bcd58a = $(`&lt;div id=&quot;html_cf6a9f18d1effd7aae5871b0c2bcd58a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GCUST&lt;/div&gt;`)[0];
#                 popup_eb51e0140988d045a006449577b6ccd6.setContent(html_cf6a9f18d1effd7aae5871b0c2bcd58a);
#
#
#
#         marker_6ce2ea6dd977707f173c5bbed02da5f8.bindPopup(popup_eb51e0140988d045a006449577b6ccd6)
#         ;
#
#
#
#
#             var marker_cb99f06bb95cf133d8692ed510b2425f = L.marker(
#                 [-19.9803, -44.0574],
#                 {}
#             ).addTo(map_97e63e2294b874e399894d8b51b7f357);
#
#
#             var icon_9426db1f6f525d9b1127b9a7a7e5391a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cb99f06bb95cf133d8692ed510b2425f.setIcon(icon_9426db1f6f525d9b1127b9a7a7e5391a);
#
#
#         var popup_c28848471e82c2456b93eccc5b15e222 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad56c135f8fcf6782ca256afc39a3812 = $(`&lt;div id=&quot;html_ad56c135f8fcf6782ca256afc39a3812&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hedson&lt;/div&gt;`)[0];
#                 popup_c28848471e82c2456b93eccc5b15e222.setContent(html_ad56c135f8fcf6782ca256afc39a3812);
#
#
#
#         marker_cb99f06bb95cf133d8692ed510b2425f.bindPopup(popup_c28848471e82c2456b93eccc5b15e222)
#         ;
#
#
#
#
#             var marker_7196c7b3c1770fb38c8abee8189ca2c0 = L.marker(
#                 [-19.844487, -43.939143],
#                 {}
#             ).addTo(map_97e63e2294b874e399894d8b51b7f357);
#
#
#             var icon_77fd68b42e1901903bfa5fb3b0c9ce24 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7196c7b3c1770fb38c8abee8189ca2c0.setIcon(icon_77fd68b42e1901903bfa5fb3b0c9ce24);
#
#
#         var popup_e44c38baf5f0941bb99e22ce80d5759f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c4892d8863e68a76dc06fc0399c8ba2 = $(`&lt;div id=&quot;html_9c4892d8863e68a76dc06fc0399c8ba2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Joâo Paulo&lt;/div&gt;`)[0];
#                 popup_e44c38baf5f0941bb99e22ce80d5759f.setContent(html_9c4892d8863e68a76dc06fc0399c8ba2);
#
#
#
#         marker_7196c7b3c1770fb38c8abee8189ca2c0.bindPopup(popup_e44c38baf5f0941bb99e22ce80d5759f)
#         ;
#
#
#
#
#             var marker_728446cb9885c780166d6cfd6eb7091f = L.marker(
#                 [-19.905747, -44.01252],
#                 {}
#             ).addTo(map_97e63e2294b874e399894d8b51b7f357);
#
#
#             var icon_bf0747fbce03579f29b2cb157e52d544 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quo

# %%
mymap.save('mapa.html')
