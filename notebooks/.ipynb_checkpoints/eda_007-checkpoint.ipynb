# %%
import pandas as pd
df1= pd.read_csv("~/Downloads/prefeit-202311.txt", encoding= "latin1", sep= ";", header= None)
df2= pd.read_csv("~/Downloads/prefeit-202309.txt", encoding= "latin1", sep= ";", header= None)
display(df1.shape)
df1.head().T
# Out:
# (1927, 26)
#                                            0  \
# 0                                        1.0
# 1                                168539942.0
# 2                                120212099.0
# 3        PREF M BELO HORIZONTE
# 4                                         MU
# 5                                         R
# 6   AMERICO MAGALHAES
# 7                                     1001.0
# 8                                310620058.0
# 9             BELO HORIZONTE
# 10                                      RAFE
# 11                                8/11/2023
# 12                                      60.0
# 13                              Y22G 1459029
# 14                                      35.0
# 15                                       0.0
# 16                                    318,42
# 17                                    334,45
# 18                                         0
# 19                                    -16,03
# 20                                         0
# ...

# %%
display(df2.shape)
df2.head().T
# Out:
# (1910, 16)
#                                                     0  \
# 0                                            12423700
# 1                                              499,93
# 2                                                  32
# 3                                                  32
# 4                                                  32
# 5                                                  32
# 6                 PREF M BELO HORIZONTE C C VEND NOVA
# 7   A15F 0038132                                  ...
# 8                                          20/10/2023
# 9                                                  R
# 10           EXPEDICIONARIO AMERICO FERNANDES
# 11                                                116
# 12
# 13
# 14                     SAO JOAO BATISTA(VN)
# 15                                                  .
#
#                                                     1  \
# 0                                           121060454
# ...
