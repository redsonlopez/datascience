# %%
library(ggplot2)
desempenho = c(5,3,7,4)
nomes= c("A","B","C","D")
produtividade = data.frame(desempenho, nomes)
ggplot(produtividade, aes(x = nomes, y = desempenho)) +
geom_bar(stat = "summary", fun = mean)
# Out:
# plot without title
