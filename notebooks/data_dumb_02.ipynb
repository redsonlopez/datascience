# %%
import pandas as pd
import numpy as np

data = {
    'Feature1': np.round(np.random.uniform(-5.0, 100.0, size=50), 1),
    'Feature2': np.round(np.random.uniform(-5.0, 100.0, size=50), 1)
}

df = pd.DataFrame(data)

df.to_excel('/content/drive/MyDrive/database/data_dumb.xlsx', index=False)

df.head()
# Out:
#    Feature1  Feature2
# 0      22.7      61.0
# 1      53.3      63.1
# 2      36.6      14.2
# 3      98.4      43.3
# 4      31.2      98.0
