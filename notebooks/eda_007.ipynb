# %%
import pandas as pd
df1= pd.read_csv("~/Downloads/prefeit-202311.txt", encoding= "latin1", sep= ";")
df2= pd.read_csv("~/Downloads/prefeit-202309.txt", encoding= "latin1", sep= ";")
display(df1.shape)
df1.head().T
# Out:
# (1926, 26)
#                                                                                  0  \
# 1.0                                                                            1.0
# 168539942.0                                                            155712292.0
# 120212099.0                                                            155706187.0
# PREF M BELO HORIZONTE                          PREF M BELO HORIZONTE PRACA
# MU                                                                              MU
# R                                                                               R
# AMERICO MAGALHAES                         HENRY CORREA DE ARAUJO
# 1001.0                                                                         0.0
# 310620058.0                                                            310620058.0
# BELO HORIZONTE                                      BELO HORIZONTE
# RAFE                                                                          RAFE
# ...

# %%
display(df2.shape)
df2.head().T
# Out:
# (1909, 16)
#                                                                                                     0  \
# 00012423700                                                                                 121060454
#        499,93                                                                                   26,69
# 000000032                                                                                           0
# 000000032.1                                                                                         0
# 000000032.2                                                                                         0
# 000000032.3                                                                                         0
# PREF M BELO HORIZONTE C C VEND NOVA                               PREF M BELO HORIZONTE PRACA
# A15F 0038132                                   ...  Y19G 0733174                                  ...
# ...
