# %%
import pandas as pd
df= pd.read_csv("~/Downloads/prefeit-202309.txt", encoding= "latin1", sep= ";")
display(df.shape)
df.head().T
# Out:
# (1909, 16)
#                                                                                                     0  \
# 00012423700                                                                                 121060454
#        499,93                                                                                   26,69
# 000000032                                                                                           0
# 000000032.1                                                                                         0
# 000000032.2                                                                                         0
# 000000032.3                                                                                         0
# PREF M BELO HORIZONTE C C VEND NOVA                               PREF M BELO HORIZONTE PRACA
# A15F 0038132                                   ...  Y19G 0733174                                  ...
# ...
