# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig= plt.figure(figsize= (6, 3))
ax1= fig.add_subplot(1, 2, 1)
ax1.plot([1, 2, 3], [10, 20, 30])
ax2= fig.add_subplot(1, 2, 2)
ax2.plot([3, 2, 1], [10, 20, 30])

# %%
fig, ax= plt.subplots(1, 2)

fig.suptitle("Figura", fontsize= 18)

ax[0].plot([2, 4, 6], [15, 45, 60])
ax[0].set_title("Subplot 1")

ax[1].plot([1, 5, 7], [25, 30, 45])
ax[1].set_title("Subplot 2")

plt.tight_layout()
plt.show()

# %%
df_1= sns.load_dataset("flights")

df_1.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.barplot(data= df_1, x= "month", y= "passengers")
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
ax= sns.lineplot(data= df_1, x= "year", y= "passengers")

# %%
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
ax= sns.histplot(data= df_1, x= "passengers")

# %%
ax= sns.boxplot(data= df_1, y= "passengers")

# %%
df_iris= sns.load_dataset("iris")
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax= sns.scatterplot(data= df_iris, x= "petal_length", y= "petal_width", hue= "species")
