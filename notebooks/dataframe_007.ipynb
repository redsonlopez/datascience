# %% [markdown]
# ##<b>Estudo Pandas</b><br><i>Parte 02

# %%
import pandas as pd
import matplotlib.pyplot as plt


#Montar drive google
from google.colab import drive
drive.mount('/content/drive')

#Vários outputs de uma única célula
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

iris = pd.read_csv('/content/drive/MyDrive/database/iris.xls')

iris.head(2)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa

# %%
iris.tail(2)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#Linhas Nulas
iris.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#Tipos Variaveis
iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
#Filtrar
grupo_a = iris[iris['PetalWidthCm']>2.3]

grupo_a.head(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 109  110            7.2           3.6            6.1           2.5
# 114  115            5.8           2.8            5.1           2.4
# 136  137            6.3           3.4            5.6           2.4
# 140  141            6.7           3.1            5.6           2.4
# 144  145            6.7           3.3            5.7           2.5
#
#             Species
# 100  Iris-virginica
# 109  Iris-virginica
# 114  Iris-virginica
# 136  Iris-virginica
# 140  Iris-virginica
# 144  Iris-virginica

# %%
#Trazer linha 0 à 4 da tabela
iris.iloc[0:5]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Linha 0 à 5 das 4 primeiras colunas
iris.iloc[0:5, 0:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm
# 0   1            5.1           3.5
# 1   2            4.9           3.0
# 2   3            4.7           3.2
# 3   4            4.6           3.1
# 4   5            5.0           3.6

# %%
#Linhas e Colunas Selecionadas
iris.loc[0:5, ['Id', 'Species']]
# Out:
#    Id      Species
# 0   1  Iris-setosa
# 1   2  Iris-setosa
# 2   3  Iris-setosa
# 3   4  Iris-setosa
# 4   5  Iris-setosa
# 5   6  Iris-setosa

# %%
#Índices
iris.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
#Valores estatísticos, mean(mediana), std(desvio-padrão)
iris.describe()
#Quantidades por catégoria (duas saídas na mesma célula)
iris['Species'].value_counts()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris.rename(columns = {'SepalLengthCm': 'SépalaComprimentoCm', 'SepalWidthCm': 'SépalaLarguraCm', 'PetalLengthCm': 'PétalaComprimentoCm', 'PetalWidthCm': 'PétalaLarguraCm', 'Species': 'Espécies'}, inplace = True)

iris.head()
# Out:
#    Id  SépalaComprimentoCm  SépalaLarguraCm  PétalaComprimentoCm  \
# 0   1                  5.1              3.5                  1.4
# 1   2                  4.9              3.0                  1.4
# 2   3                  4.7              3.2                  1.3
# 3   4                  4.6              3.1                  1.5
# 4   5                  5.0              3.6                  1.4
#
#    PétalaLarguraCm     Espécies
# 0              0.2  Iris-setosa
# 1              0.2  Iris-setosa
# 2              0.2  Iris-setosa
# 3              0.2  Iris-setosa
# 4              0.2  Iris-setosa

# %%
plt.scatter(iris['SépalaComprimentoCm'], iris['PétalaLarguraCm']);

# %%
# %who
# Out:
# InteractiveShell	 drive	 grupo_a	 iris	 pd	 plt

# %%
# %history
# Out:
# import pandas as pd
# import matplotlib.pyplot as plt
#
#
# #Montar drive google
# from google.colab import drive
# drive.mount('/content/drive')
#
# #Vários outputs de uma única célula
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = 'all'
#
# iris = pd.read_csv('/content/drive/MyDrive/database/iris.xls')
#
# iris.head(2)
# iris.tail(2)
# iris.info()
# #Linhas Nulas
# iris.isna().sum()
# #Tipos Variaveis
# iris.dtypes
# #Filtrar
# grupo_a = iris[iris['PetalWidthCm']>2.3]
#
# grupo_a.head(10)
# #Trazer linha 0 à 4 da tabela
# iris.iloc[0:5]
# #Linha 0 à 5 das 4 primeiras colunas
# iris.iloc[0:5, 0:3]
# #Linhas e Colunas Selecionadas
# iris.loc[0:5, ['Id', 'Species']]
# #Índices
# iris.index
# #Valores estatísticos, mean(mediana), std(desvio-padrão)
# iris.describe()
# #Quantidades por catégoria (duas saídas na mesma célula)
# iris['Species'].value_counts()
# iris['Species'].unique()
# iris.columns
# ...
