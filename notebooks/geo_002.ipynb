# %%
import pandas as pd
import folium

df= pd.read_csv("~/Downloads/Saúde - Fidedigna.csv")
print(f"Linhas= {df.shape[0]}, Colunas= {df.shape[1]}")
# Out:
# Linhas= 432, Colunas= 199

# %%
atributos= ["FOI REALIZADA VISITA?", "REGIONAL", "UNIDADE DE SAÚDE", "LOGRADOURO POR GEORREFERENCIAMENTO", 
            "NOME DO LOGRADOURO POR GEORREFERENCIAMENTO", "NÚMERO POR GEORREFERENCIAMENTO", "BAIRRO",
            "COORDENADAS GEOGRÁFICAS POR GEORREFERENCIAMENTO"]
df= df[atributos]
df= df[df["FOI REALIZADA VISITA?"] == "NÃO"]
print(f"Linhas= {df.shape[0]}, Colunas= {df.shape[1]}")
# Out:
# Linhas= 47, Colunas= 8

# %%
df[['Latitude', 'Longitude']] = df['COORDENADAS GEOGRÁFICAS POR GEORREFERENCIAMENTO'].str.rsplit(',', n=1, expand=True).astype(float)
display(df.head(2))
df.shape
# Out:
#    FOI REALIZADA VISITA?    REGIONAL  \
# 46                   NÃO  CENTRO-SUL
# 61                   NÃO  CENTRO-SUL
#
#                                    UNIDADE DE SAÚDE  \
# 46                   ACADEMIA DA CIDADE VILA FÁTIMA
# 61  CENTRO DE REFERÊNCIA EM REABILITAÇÃO CENTRO-SUL
#
#    LOGRADOURO POR GEORREFERENCIAMENTO  \
# 46                               BECO
# 61                                RUA
#
#    NOME DO LOGRADOURO POR GEORREFERENCIAMENTO NÚMERO POR GEORREFERENCIAMENTO  \
# 46                                 DONA BENTA                            145
# 61      PROFESSOR OCTAVIO COELHO DE MAGALHAES                            111
#
#                      BAIRRO COORDENADAS GEOGRÁFICAS POR GEORREFERENCIAMENTO  \
# 46  NOSSA SENHORA DE FATIMA                      -19.93440545, -43.90432633
# 61              MANGABEIRAS                      -19.94879522, -43.91706728
#
#      Latitude  Longitude
# 46 -19.934405 -43.904326
# 61 -19.948795 -43.917067
# (47, 10)

# %%
# Criar um mapa
mymap = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=12)

folium.Marker([-19.924533, -43.936590], popup= "GCUST", icon= folium.Icon(color= "red", icon= "info-sign")).add_to(mymap)
folium.Marker([-19.980314, -44.057487], popup= "Hedson", icon= folium.Icon(color= "darkred", icon= "info-sign")).add_to(mymap)

# Adicionar marcadores ao mapa
for index, row in df.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], popup= "{}, {}, {}, {}, {}"
                  .format(row['UNIDADE DE SAÚDE'], row['LOGRADOURO POR GEORREFERENCIAMENTO'], row['NOME DO LOGRADOURO POR GEORREFERENCIAMENTO'],
                          row['NÚMERO POR GEORREFERENCIAMENTO'], row["BAIRRO"])).add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5263fa017b3bbdaab8542e43e215483 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5263fa017b3bbdaab8542e43e215483&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5263fa017b3bbdaab8542e43e215483 = L.map(
#                 &quot;map_f5263fa017b3bbdaab8542e43e215483&quot;,
#                 {
#                     center: [-19.929711089361707, -43.933872429999994],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb9ca657483d529dd3315a326e596653 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bb9ca657483d529dd3315a326e596653.addTo(map_f5263fa017b3bbdaab8542e43e215483);
#
#
#             var marker_9232e85f2219afcff23ce592fc8d0969 = L.marker(
#                 [-19.924533, -43.93659],
#                 {}
#             ).addTo(map_f5263fa017b3bbdaab8542e43e215483);
#
#
#             var icon_7722ab889c4a3b02a54d67cebccb5f2f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9232e85f2219afcff23ce592fc8d0969.setIcon(icon_7722ab889c4a3b02a54d67cebccb5f2f);
#
#
#         var popup_6cda7d6eb4696c33dd9403f51b902857 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8cd79c283763bb75011ad283ed7f459f = $(`&lt;div id=&quot;html_8cd79c283763bb75011ad283ed7f459f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;GCUST&lt;/div&gt;`)[0];
#                 popup_6cda7d6eb4696c33dd9403f51b902857.setContent(html_8cd79c283763bb75011ad283ed7f459f);
#
#
#
#         marker_9232e85f2219afcff23ce592fc8d0969.bindPopup(popup_6cda7d6eb4696c33dd9403f51b902857)
#         ;
#
#
#
#
#             var marker_652dbc68d1b538abb7d2ef08e49bf73c = L.marker(
#                 [-19.980314, -44.057487],
#                 {}
#             ).addTo(map_f5263fa017b3bbdaab8542e43e215483);
#
#
#             var icon_4585ae86c6334b276b2630bc8d3e9033 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_652dbc68d1b538abb7d2ef08e49bf73c.setIcon(icon_4585ae86c6334b276b2630bc8d3e9033);
#
#
#         var popup_0dea65a1c60198e57a4005b93d51c673 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50877a1ecef5ac0a97478db0927a9c4e = $(`&lt;div id=&quot;html_50877a1ecef5ac0a97478db0927a9c4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hedson&lt;/div&gt;`)[0];
#                 popup_0dea65a1c60198e57a4005b93d51c673.setContent(html_50877a1ecef5ac0a97478db0927a9c4e);
#
#
#
#         marker_652dbc68d1b538abb7d2ef08e49bf73c.bindPopup(popup_0dea65a1c60198e57a4005b93d51c673)
#         ;
#
#
#
#
#             var marker_4c8d6703014f46365734000ef51ba942 = L.marker(
#                 [-19.93440545, -43.90432633],
#                 {}
#             ).addTo(map_f5263fa017b3bbdaab8542e43e215483);
#
#
#         var popup_17ba88ac130bfb6b178a81a535aca02a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_378306220e0408d81d58ce9f0e1fe768 = $(`&lt;div id=&quot;html_378306220e0408d81d58ce9f0e1fe768&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ACADEMIA DA CIDADE VILA FÁTIMA, BECO, DONA BENTA, 145, NOSSA SENHORA DE FATIMA&lt;/div&gt;`)[0];
#                 popup_17ba88ac130bfb6b178a81a535aca02a.setContent(html_378306220e0408d81d58ce9f0e1fe768);
#
#
#
#         marker_4c8d6703014f46365734000ef51ba942.bindPopup(popup_17ba88ac130bfb6b178a81a535aca02a)
#         ;
#
#
#
#
#             var marker_d3e7f4c288b689389bc64edc132eb0b8 = L.marker(
#                 [-19.94879522, -43.91706728],
#                 {}
#             ).addTo(map_f5263fa017b3bbdaab8542e43e215483);
#
#
#         var popup_ec5f9981ed13483c286f3631a85ea2ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f6a1a044ef7aa8f98ae6345e3ce051b3 = $(`&lt;div id=&quot;html_f6a1a044ef7aa8f98ae6345e3ce051b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CENTRO DE REFERÊNCIA EM REABILITAÇÃO CENTRO-SUL, RUA, PROFESSOR OCTAVIO COELHO DE MAGALHAES, 111, MANGABEIRAS&lt;/div&gt;`)[0];
#                 popup_ec5f9981ed13483c286f3631a85ea2ba.setContent(html_f6a1a044ef7aa8f98ae6345e3ce051b3);
#
#
#
#         marker_d3e7f4c288b689389bc64edc

# %%
mymap.save('mapa.html')
