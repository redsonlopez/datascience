# %%
# Dados de treinamento X e seus respectivos rótulos y
X = ...  # Complete com seus dados de treinamento (matriz com as features)
y = ...  # Complete com seus rótulos de treinamento (vetor com as labels)

# Criando e treinando o modelo ElasticNet
from sklearn.linear_model import ElasticNet
elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5) # r= 0 (Ridge), r= 1 (Lasso)
elastic_net.fit(X, y)

# Realizando a previsão para um novo exemplo [1.5]
novo_exemplo = [[1.5]]
previsao = elastic_net.predict(novo_exemplo)
print(previsao)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but ElasticNet was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-6f50bb2afd67> in <cell line: 15>()
#      13 # Realizando a previsão para um novo exemplo [1.5]
#      14 novo_exemplo = [[1.5]]
# ---> 15 previsao = elastic_net.predict(novo_exemplo)
#      16 print(previsao)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     352             Returns predicted values.
#     353         """
# --> 354         return self._decision_function(X)
#     355
#     356     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py in _decision_function(self, X)
# ...
