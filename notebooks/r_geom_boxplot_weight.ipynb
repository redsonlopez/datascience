# %%
library(ggplot2)
peso = c(65, 66, 85, 72, 95, 73, 75, 89, 69, 70)
altura = c(170, 175, 183, 175, 176, 350, 176, 423, 63, 176)
dados = data.frame(peso, altura)
ggplot(dados, aes(x = peso, y = altura, group = 3)) +
geom_boxplot()
# Out:
# plot without title
