# %% [markdown]
# # <b>Programação Orientada a Objetos<br></b>
# <i>Estudo 01_2<br>
# Registro para Loja.

# %%
#@title Classe Vendas
class Vendas:
  historico_de_vendas= "s3://nome_do_buquet/historico_de_vendas.csv"

  def registrar_venda(self, codigo_cliente, codigo_produto, quantidade, valor_total):
    """
    Registra uma nova venda na tabela vendas
    """
    pass

  def cancelar_venda(self, codigo_venda):
    """
    Cancela uma venda registrada
    """
    pass

  def consultar_venda(self, codigo_venda):
    """
    Exibe as informações detalhadas da venda informada
    """
    pass

# %%
class Produtos:
  cadastro_de_produtos= "s3://nome_do_buquet/cadastro_de_produtos.csv"

  def registrar_produto(self, nome_produto):
    """
    Registra um novo produto no cadastro,
    gerando um código de identificação único para esse produto.
    """
    pass

  def alterar_produto(self, codigo_produto, novo_nome):
    """
    Altera o nome de um produto cadastrado.
    """
    pass

  def remover_produto(self, codigo_produto):
    """
    Remove um produto específico do cadastro de produtos.
    """
    pass

# %%
class Clientes:
  cadastro_de_clientes= "s3://nome_do_buquet/cadastro_de_clientes.csv"

  def registrar_cliente(self, nome_cliente, endereco_entrega):
    """
    Registra um novo cliente no cadastro,
    gerando um código de identificação único para este cliente.
    """
    pass

  def alterar_endereco(self, codigo_cliente, novo_endereco):
    """
    Altera o endereço de entrega de um cliente cadastrado.
    """
    pass

  def remover_loja(self, codigo_cliente):
    """
    Remove um cliente específico do cadastro
    """
    pass

# %% [markdown]
# ## Diagrama das classes Vendas, Produtos e Clientes:
# ![loja.png](data:image/png;base64,...)
