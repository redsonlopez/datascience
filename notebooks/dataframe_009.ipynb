# %% [markdown]
# ##<b>Estudo Pandas</b><br><i>Parte 03

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

fifa = pd.read_csv('/content/drive/MyDrive/database/fifa19.csv')

fifa.head(3)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# ...

# %%
fifa.loc[1:3]
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
#
#                                             Photo Nationality  \
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
#
#                                   Flag  Overall  Potential  \
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# ...

# %%
fifa.loc[0:5, 'Name']
# Out:
# 0             L. Messi
# 1    Cristiano Ronaldo
# 2            Neymar Jr
# 3               De Gea
# 4         K. De Bruyne
# 5            E. Hazard
# Name: Name, dtype: object

# %%
filtro_1 = fifa.iloc[0:10, 0:3]
filtro_1.tail()
# Out:
#    Unnamed: 0      ID          Name
# 5           5  183277     E. Hazard
# 6           6  177003     L. Modrić
# 7           7  176580     L. Suárez
# 8           8  155862  Sergio Ramos
# 9           9  200389      J. Oblak

# %%
filtro_2 = fifa.iloc[:, 0:3]
filtro_2.tail()
# Out:
#        Unnamed: 0      ID                Name
# 18202       18202  238813        J. Lundstram
# 18203       18203  243165  N. Christoffersson
# 18204       18204  241638           B. Worman
# 18205       18205  246268      D. Walker-Rice
# 18206       18206  246269           G. Nugent

# %%
fifa.loc[(fifa['Age']>30) & (fifa['Overall']>90)] # e = &; ou = |
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 8  https://cdn.sofifa.org/players/4/19/155862.png       Spain
#
#                                   Flag  Overall  Potential          Club  ...  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94  FC Barcelona  ...
# 1  https://cdn.sofifa.org/flags/38.png       94         94      Juventus  ...
# ...

# %%
tiozoes_do_fifa = fifa.query('Age > 30')
tiozoes_do_fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 8  https://cdn.sofifa.org/players/4/19/155862.png       Spain
#
#                                   Flag  Overall  Potential          Club  ...  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94  FC Barcelona  ...
# 1  https://cdn.sofifa.org/flags/38.png       94         94      Juventus  ...
# ...

# %%
fifa.query('Age > 30 & Overall > 90')
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 8  https://cdn.sofifa.org/players/4/19/155862.png       Spain
#
#                                   Flag  Overall  Potential          Club  ...  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94  FC Barcelona  ...
# 1  https://cdn.sofifa.org/flags/38.png       94         94      Juventus  ...
# ...

# %%
overall_mediana = fifa['Overall'].median()
fifa.query('Overall > @overall_mediana')
# Out:
#       Unnamed: 0      ID               Name  Age  \
# 0              0  158023           L. Messi   31
# 1              1   20801  Cristiano Ronaldo   33
# 2              2  190871          Neymar Jr   26
# 3              3  193080             De Gea   27
# 4              4  192985       K. De Bruyne   27
# ...          ...     ...                ...  ...
# 8759        8759  224509           U. Rivas   22
# 8760        8760  214014        C. Lizarazo   27
# 8761        8761  104702         D. Braaten   36
# 8762        8762  229631               Lazo   22
# 8763        8763  246015            L. Mago   23
#
#                                                Photo Nationality  \
# 0     https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1      https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2     https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3     https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
fifa.query('Nationality == "Brazil"')
# Out:
#        Unnamed: 0      ID              Name  Age  \
# 2               2  190871         Neymar Jr   26
# 27             27  200145          Casemiro   26
# 32             32  189242          Coutinho   26
# 35             35  176676           Marcelo   30
# 39             39  164240      Thiago Silva   33
# ...           ...     ...               ...  ...
# 17059       17059  243750  Gianluca Zanette   21
# 17446       17446  235949         Strefezza   21
# 17588       17588  244311     Lucas Ribeiro   19
# 17611       17611  241268   Felipe Ferreyra   20
# 18170       18170  246447   Nicolas Firmino   17
#
#                                                 Photo Nationality  \
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 27     https://cdn.sofifa.org/players/4/19/200145.png      Brazil
# 32     https://cdn.sofifa.org/players/4/19/189242.png      Brazil
# 35     https://cdn.sofifa.org/players/4/19/176676.png      Brazil
# ...

# %%
fifa['Age'] > 30
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Name: Age, Length: 18207, dtype: bool

# %%
fifa[fifa['Age'] > 30]
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   31
# 1               1   20801  Cristiano Ronaldo   33
# 6               6  177003          L. Modrić   32
# 7               7  176580          L. Suárez   31
# 8               8  155862       Sergio Ramos   32
# ...           ...     ...                ...  ...
# 17842       17842  182461          Zhou Ting   39
# 17866       17866  232676           N. Hatta   32
# 18043       18043  237917          A. Suzuki   31
# 18171       18171  237746        Y. Uchimura   33
# 18183       18183   53748      K. Pilkington   44
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 6      https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7      https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# ...

# %%
fifa[fifa['GKDiving']==fifa['GKHandling']]
# Out:
#        Unnamed: 0      ID          Name  Age  \
# 2               2  190871     Neymar Jr   26
# 24             24  138956  G. Chiellini   33
# 26             26  209331      M. Salah   26
# 28             28  198710  J. Rodríguez   26
# 36             36  173731       G. Bale   28
# ...           ...     ...           ...  ...
# 18153       18153  246270    M. Dyrmose   17
# 18156       18156  245533     J. Devine   18
# 18192       18192  245571     S. Squire   18
# 18194       18194  245862      J. Milli   18
# 18199       18199  244677  M. Baldisimo   18
#
#                                                 Photo Nationality  \
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 24     https://cdn.sofifa.org/players/4/19/138956.png       Italy
# 26     https://cdn.sofifa.org/players/4/19/209331.png       Egypt
# 28     https://cdn.sofifa.org/players/4/19/198710.png    Colombia
# 36     https://cdn.sofifa.org/players/4/19/173731.png       Wales
# ...

# %%
filtro = fifa.filter(['Age', 'Name', 'Overall', 'Nationality', 'Club']).sort_values(by= 'Overall', ascending= False)
filtro.head()
# Out:
#    Age               Name  Overall Nationality                 Club
# 0   31           L. Messi       94   Argentina         FC Barcelona
# 1   33  Cristiano Ronaldo       94    Portugal             Juventus
# 2   26          Neymar Jr       92      Brazil  Paris Saint-Germain
# 3   27             De Gea       91       Spain    Manchester United
# 4   27       K. De Bruyne       91     Belgium      Manchester City

# %%
champs = fifa[fifa['Nationality'].isin(['Argentina', 'Brazil', 'Germany', 'France', 'Italy', 'England'])]
champs.head()
# Out:
#     Unnamed: 0      ID       Name  Age  \
# 0            0  158023   L. Messi   31
# 2            2  190871  Neymar Jr   26
# 11          11  182521   T. Kroos   28
# 14          14  215914   N. Kanté   27
# 15          15  211110  P. Dybala   24
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 2   https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 11  https://cdn.sofifa.org/players/4/19/182521.png     Germany
# 14  https://cdn.sofifa.org/players/4/19/215914.png      France
# 15  https://cdn.sofifa.org/players/4/19/211110.png   Argentina
#
#                                    Flag  Overall  Potential  \
# 0   https://cdn.sofifa.org/flags/52.png       94         94
# 2   https://cdn.sofifa.org/flags/54.png       92         93
# 11  https://cdn.sofifa.org/flags/21.png       90         90
# 14  https://cdn.sofifa.org/flags/18.png       89         90
# ...

# %%
no_champs = fifa[~fifa['Nationality'].isin(['Argentina', 'Brazil', 'Germany', 'France', 'Italy', 'England'])]
no_champs.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 1           1   20801  Cristiano Ronaldo   33
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
#
#                                             Photo Nationality  \
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
#
#                                   Flag  Overall  Potential               Club  \
# 1  https://cdn.sofifa.org/flags/38.png       94         94           Juventus
# 3  https://cdn.sofifa.org/flags/45.png       91         93  Manchester United
# ...

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
fifa_numerics = fifa.select_dtypes(include = numerics)
fifa_non_numerics = fifa.select_dtypes(exclude = numerics)

fifa_non_numerics.head()
# Out:
#                 Name                                           Photo  \
# 0           L. Messi  https://cdn.sofifa.org/players/4/19/158023.png
# 1  Cristiano Ronaldo   https://cdn.sofifa.org/players/4/19/20801.png
# 2          Neymar Jr  https://cdn.sofifa.org/players/4/19/190871.png
# 3             De Gea  https://cdn.sofifa.org/players/4/19/193080.png
# 4       K. De Bruyne  https://cdn.sofifa.org/players/4/19/192985.png
#
#   Nationality                                 Flag                 Club  \
# 0   Argentina  https://cdn.sofifa.org/flags/52.png         FC Barcelona
# 1    Portugal  https://cdn.sofifa.org/flags/38.png             Juventus
# 2      Brazil  https://cdn.sofifa.org/flags/54.png  Paris Saint-Germain
# 3       Spain  https://cdn.sofifa.org/flags/45.png    Manchester United
# 4     Belgium   https://cdn.sofifa.org/flags/7.png      Manchester City
#
#                                       Club Logo    Value   Wage  \
# ...

# %%
fifa.sort_values(by= 'Overall', ascending= True).head()
# Out:
#        Unnamed: 0      ID          Name  Age  \
# 18206       18206  246269     G. Nugent   16
# 18186       18186  240917  Zhang Yufeng   20
# 18187       18187  240158     C. Ehlich   19
# 18188       18188  240927    L. Collins   17
# 18189       18189  240160    A. Kaltner   18
#
#                                                 Photo Nationality  \
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
# 18186  https://cdn.sofifa.org/players/4/19/240917.png    China PR
# 18187  https://cdn.sofifa.org/players/4/19/240158.png     Germany
# 18188  https://cdn.sofifa.org/players/4/19/240927.png       Wales
# 18189  https://cdn.sofifa.org/players/4/19/240160.png     Germany
#
#                                        Flag  Overall  Potential  \
# 18206   https://cdn.sofifa.org/flags/14.png       46         66
# 18186  https://cdn.sofifa.org/flags/155.png       47         64
# 18187   https://cdn.sofifa.org/flags/21.png       47         59
# ...

# %%
fifa.drop_duplicates() # Remove linhas duplicadas
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...
