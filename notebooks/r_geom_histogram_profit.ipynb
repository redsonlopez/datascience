# %%
lucro = c(3.34, -2.18, 4.14, 0.33, 7.4, 0.32, -0.25, 1.15, 2.34, 5.67, 8.76, 3.33, 1.23, 2.56, 6.44, 1.23, 0.65, 3.33, 4.44, -0.21, 0.76, 1.43, 1.33, 6.32, 8.21, 3.12, 0.22, 2.22, 7.65, 8.11, 2.11, 5.22, 9.87, 5.44, 3.32)
dados = data.frame(lucro)
hist(lucro)
# Out:
# Plot with title “Histogram of lucro”
