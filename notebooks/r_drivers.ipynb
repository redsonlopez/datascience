# %%
corredor = c("Avarias 5L", "Avarias A", "Compras A", "Compras B", "Bagunça A", "Bagunça B", "Produção A", "Produção B")
drivers = c(12, 7, 19, 19, 19, 12, 6, 6)
pallets = c(15, 12, 12, 12, 12, 12, 24, 18)
dados <- data.frame(corredor, drivers, pallets)

total = drivers * pallets

espaco = sum(total)
print("Total de Drivers:")
print(espaco)

caixas = sum(total * 45)
print("Média Total de Caixas:")
print(caixas)

print(dados)
# Out:
# [1] "Total de Drivers:"
# [1] 1344
# [1] "Média Total de Caixas:"
# [1] 60480
#     corredor drivers pallets
# 1 Avarias 5L      12      15
# 2  Avarias A       7      12
# 3  Compras A      19      12
# 4  Compras B      19      12
# 5  Bagunça A      19      12
# 6  Bagunça B      12      12
# 7 Produção A       6      24
# 8 Produção B       6      18
