# %% [markdown]
# ##<b>Estudo Pandas</b><br><i>Parte 04

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/database/fifa19.csv')

df.head(3)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# ...

# %%
df_null = df[['ID', 'Name', 'LCB', 'LB']].head(10)
df_null
# Out:
#        ID               Name   LCB    LB
# 0  158023           L. Messi  47+2  59+2
# 1   20801  Cristiano Ronaldo  53+3  61+3
# 2  190871          Neymar Jr  47+3  60+3
# 3  193080             De Gea   NaN   NaN
# 4  192985       K. De Bruyne  66+3  73+3
# 5  183277          E. Hazard  49+3  60+3
# 6  177003          L. Modrić  71+3  79+3
# 7  176580          L. Suárez  63+5  66+5
# 8  155862       Sergio Ramos  87+3  84+3
# 9  200389           J. Oblak   NaN   NaN

# %%
df_null.isna()
# Out:
#       ID   Name    LCB     LB
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True   True
# 4  False  False  False  False
# 5  False  False  False  False
# 6  False  False  False  False
# 7  False  False  False  False
# 8  False  False  False  False
# 9  False  False   True   True

# %%
df_null.isna().sum()
# Out:
# ID      0
# Name    0
# LCB     2
# LB      2
# dtype: int64

# %%
df_null[pd.isna(df_null['LCB'])] # Filtrar linhas missing
# Out:
#        ID      Name  LCB   LB
# 3  193080    De Gea  NaN  NaN
# 9  200389  J. Oblak  NaN  NaN

# %%
df_null[df_null['LCB'].notna()] # Filtra quem não tem missing
# Out:
#        ID               Name   LCB    LB
# 0  158023           L. Messi  47+2  59+2
# 1   20801  Cristiano Ronaldo  53+3  61+3
# 2  190871          Neymar Jr  47+3  60+3
# 4  192985       K. De Bruyne  66+3  73+3
# 5  183277          E. Hazard  49+3  60+3
# 6  177003          L. Modrić  71+3  79+3
# 7  176580          L. Suárez  63+5  66+5
# 8  155862       Sergio Ramos  87+3  84+3

# %%
df_null.fillna('0')
# Out:
#        ID               Name   LCB    LB
# 0  158023           L. Messi  47+2  59+2
# 1   20801  Cristiano Ronaldo  53+3  61+3
# 2  190871          Neymar Jr  47+3  60+3
# 3  193080             De Gea     0     0
# 4  192985       K. De Bruyne  66+3  73+3
# 5  183277          E. Hazard  49+3  60+3
# 6  177003          L. Modrić  71+3  79+3
# 7  176580          L. Suárez  63+5  66+5
# 8  155862       Sergio Ramos  87+3  84+3
# 9  200389           J. Oblak     0     0

# %%
# df_null.fillna(df_null.mean(), inplace= True) # Preencher numericos com média/ inplace= True para mudança permanente

# %%
values = {'LCB': '0', 'LB': '999999'}
df_null.fillna(value = values) # Preencher valores nulos com dicionario.
# Out:
#        ID               Name   LCB      LB
# 0  158023           L. Messi  47+2    59+2
# 1   20801  Cristiano Ronaldo  53+3    61+3
# 2  190871          Neymar Jr  47+3    60+3
# 3  193080             De Gea     0  999999
# 4  192985       K. De Bruyne  66+3    73+3
# 5  183277          E. Hazard  49+3    60+3
# 6  177003          L. Modrić  71+3    79+3
# 7  176580          L. Suárez  63+5    66+5
# 8  155862       Sergio Ramos  87+3    84+3
# 9  200389           J. Oblak     0  999999

# %%
df_null.dropna()
# Out:
#        ID               Name   LCB    LB
# 0  158023           L. Messi  47+2  59+2
# 1   20801  Cristiano Ronaldo  53+3  61+3
# 2  190871          Neymar Jr  47+3  60+3
# 4  192985       K. De Bruyne  66+3  73+3
# 5  183277          E. Hazard  49+3  60+3
# 6  177003          L. Modrić  71+3  79+3
# 7  176580          L. Suárez  63+5  66+5
# 8  155862       Sergio Ramos  87+3  84+3

# %%
df_null.dropna(subset= ['LCB']) # Exclui missing apénas presente em 'subset'
# Out:
#        ID               Name   LCB    LB
# 0  158023           L. Messi  47+2  59+2
# 1   20801  Cristiano Ronaldo  53+3  61+3
# 2  190871          Neymar Jr  47+3  60+3
# 4  192985       K. De Bruyne  66+3  73+3
# 5  183277          E. Hazard  49+3  60+3
# 6  177003          L. Modrić  71+3  79+3
# 7  176580          L. Suárez  63+5  66+5
# 8  155862       Sergio Ramos  87+3  84+3

# %%
df['Weight'].head()
# Out:
# 0    159lbs
# 1    183lbs
# 2    150lbs
# 3    168lbs
# 4    154lbs
# Name: Weight, dtype: object

# %%
df['Weight'].fillna('0lbs', inplace= True)

# %%
teste = df['Weight'].head()
teste[1].replace('lbs', '')
# Out:
# '183'

# %%
def substitui_lbs(value):
  x = value.replace('lbs', '')
  return int(x)

df['Weight_new'] = df['Weight'].apply(substitui_lbs)
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df['Wage'].head()
# Out:
# 0    €565K
# 1    €405K
# 2    €290K
# 3    €260K
# 4    €355K
# Name: Wage, dtype: object

# %%
def converte_wage(value):
    value_2= value.replace('€', '')
    if 'M' in value_2:
      value_2= value_2.replace('M', '')
      return float(value_2)* 1000000
    elif 'K' in value_2:
      value_2= value_2.replace('K', '')
      return float(value_2)* 1000

df['Wage_Numeric']= df['Wage'].apply(converte_wage)
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df['avg_GK']= (df['GKDiving']+ df['GKHandling']+ df['GKKicking']+ df['GKPositioning']+ df['GKReflexes'])/5
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df['Age_Class'] = np.where(df['Age'] > 30, 'Old', 'Young') # Esse campo condicional precisa de "Import numpy as np"
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df['Age_Class2'] = 'Young'
df.loc[df['Age'] > 30, 'Age_Class2']= 'Old'
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %% [markdown]
# ### Extras

# %%
# Criar dataframe a partir de clipboards, simplismente copie a tabela e faça:
# df_clipboard = pd.read_clipboard()

# %%
# Usar dados dummies para treinar modelos:
pd.util.testing.makeDataFrame()
# Out:
#                    A         B         C         D
# yzfHhz2DtX  0.419213  0.292328 -2.145892 -0.789018
# 7AAY422WSp -0.327768 -0.707684  0.342540  0.520885
# WzUpOWMKgl -0.413093 -1.659513 -0.726411 -1.449523
# PEKFbQsw8P -1.791168 -0.340858  0.859157  0.250713
# eA1UKfYYJh  0.191408  0.450693  0.474229 -0.510115
# m8PloTThg9  0.190607 -0.287294  0.413840 -0.016035
# o3jaao7mMK  1.039335  1.302198 -1.028167 -0.585575
# XbNVzVxuUj -0.826974 -0.951929  0.093927 -0.912096
# sRZx5GTEFZ  0.693362 -1.254100  0.795587  0.899849
# Il0Y9gg2jw  1.330254 -0.404990  1.219095 -0.008150
# rYcMVnenRU -0.228681  1.378414 -0.274498  1.528467
# Z7cheRqsKh  0.845862 -1.856209  0.156131  0.324466
# udyzgrpwAD  0.081471  0.004644 -0.819855 -0.742297
# dOKXRmzwhj  0.722048  1.197230  1.969972 -0.495506
# znTKWrcjMO  0.626188  0.146323 -1.493046 -0.212068
# XY5OZ17j0p  1.270122  0.257432 -0.388947  0.579037
# eiLNxOCRVt -0.154722 -0.865873  0.132540  0.137466
# ...
