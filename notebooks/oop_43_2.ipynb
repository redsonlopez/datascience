# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
#from sklearn.metrics import plot_confusion_matrix
#from sklearn.metrics import plot_rouc_curve, rouc_auc_score

class Performance:
  def __init__(self,clf, X_teste, y_teste):
    self.clf= clf
    self.X_teste= X_teste
    self.y_teste= y_teste
    self.y_previsto= clf.predict(X_teste)
    self.y_proba= clf.predict_proba(X_teste)[:, 1]

  @property
  def acuracia(self):
    return accuracy_score(self.y_teste, self.y_previsto)

  @property
  def precision(self):
    return precision_score(self.y_teste, self.y_previsto)

  @property
  def recall(self):
    return recall_score(self.y_teste, self.y_previsto)

  @property
  def f_score(self):
    return f1_score(self.y_teste, self.y_previto)

  @property
  def roc_auc_score(self):
    return roc_auc_score(self.y_teste, self.y_previsto)


  def plotar_matriz_confusao(self):
    return plot_confusion_matrix(self.clf, self.X_teste, self.y_teste)

  def plotar_curva_roc(self):
    return plot_rouc_curve(self.clf, self.X_teste, self.y_teste)
