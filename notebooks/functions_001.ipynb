# %% [markdown]
# #<b><i>Estudo Funções

# %%
#Retorna Numerador e Denominador:
x = 0.125
x.as_integer_ratio()
# Out:
# (1, 8)

# %%
def soma(x,y):
  resultado = x + y
  return resultado

soma(5,3)
# Out:
# 8
