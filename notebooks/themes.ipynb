# %%
# pip install jupyterthemes
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 22.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 44.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 6.2 MB/s eta 0:00:00
# ...

# %%
import jupyterthemes as jt

jt.__version__
# Out:
# '0.20.0'

# %%
jt.get_themes()
# Out:
# ['gruvboxd',
#  'onedork',
#  'solarizedl',
#  'oceans16',
#  'chesterish',
#  'monokai',
#  'solarizedd',
#  'gruvboxl',
#  'grade3']

# %%
jt.install_theme(theme= 'monokai')

# %%
X= [10, 20, 30, 40]
y= [110, 230, 360, 500]

from jupyterthemes import jtplot
jtplot.style(spines= False, gridlines= "--")

import seaborn as sns
sns.regplot(x= X, y= y);
